# %%
#import libraries
import pandas as pd
import numpy as np


# Load CSV dataset
df = pd.read_csv("irisdataset.csv")  

#display first 5 rows
df.head()
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# Checking missing values

df.isnull().sum()

# there are no missing values
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# Fitering the data 
df[df["SepalLengthCm"] > 5]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 10    11            5.4           3.7            1.5           0.2
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 5       Iris-setosa
# 10      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# ..              ...
# ...

# %%
df.groupby("SepalWidthCm").mean(numeric_only=True)
# Out:
#                       Id  SepalLengthCm  PetalLengthCm  PetalWidthCm
# SepalWidthCm
# 2.0            61.000000       5.000000       3.500000      1.000000
# 2.2            84.000000       6.066667       4.500000      1.333333
# 2.3            69.500000       5.325000       3.250000      0.975000
# 2.4            73.666667       5.300000       3.600000      1.033333
# 2.5           101.125000       5.762500       4.512500      1.550000
# 2.6           103.600000       6.160000       4.880000      1.420000
# 2.7            96.777778       5.855556       4.622222      1.555556
# 2.8           103.428571       6.335714       5.042857      1.707143
# 2.9            75.800000       6.060000       4.350000      1.320000
# 3.0            88.692308       6.015385       4.234615      1.403846
# 3.1            73.750000       5.941667       3.600000      1.141667
# 3.2            73.230769       5.884615       3.753846      1.261538
# ...

# %%
df.groupby("Species").mean(numeric_only=True)
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
df.groupby("SepalLengthCm").mean(numeric_only=True)
# Out:
#                        Id  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm
# 4.3             14.000000      3.000000       1.100000      0.100000
# 4.4             30.333333      3.033333       1.333333      0.200000
# 4.5             42.000000      2.300000       1.300000      0.300000
# 4.6             20.500000      3.325000       1.325000      0.225000
# 4.7             16.500000      3.200000       1.450000      0.200000
# 4.8             25.400000      3.180000       1.580000      0.200000
# 4.9             41.666667      2.866667       2.283333      0.533333
# 5.0             39.200000      3.120000       1.840000      0.430000
# 5.1             35.111111      3.477778       1.722222      0.400000
# 5.2             37.500000      3.425000       2.075000      0.475000
# 5.3             49.000000      3.700000       1.500000      0.200000
# 5.4             28.666667      3.550000       2.033333      0.516667
# ...

# %%
df.groupby("PetalLengthCm").mean(numeric_only=True)
# Out:
#                        Id  SepalLengthCm  SepalWidthCm  PetalWidthCm
# PetalLengthCm
# 1.0             23.000000       4.600000      3.600000      0.200000
# 1.1             14.000000       4.300000      3.000000      0.100000
# 1.2             25.500000       5.400000      3.600000      0.200000
# 1.3             31.714286       4.842857      3.228571      0.257143
# 1.4             21.833333       4.916667      3.333333      0.216667
# 1.5             24.714286       5.128571      3.535714      0.221429
# 1.6             31.000000       4.914286      3.342857      0.285714
# 1.7             17.500000       5.400000      3.600000      0.350000
# 1.9             35.000000       4.950000      3.600000      0.300000
# 3.0             99.000000       5.100000      2.500000      1.100000
# 3.3             76.000000       4.950000      2.350000      1.000000
# 3.5             70.500000       5.350000      2.300000      1.000000
# ...
